# %%
# !pip install gym[box2d] pyglet
# Out:
# Requirement already satisfied: gym[box2d] in c:\users\sas\desktop\reinforcement-learning-exercises\rl\lib\site-packages (0.21.0)
# Requirement already satisfied: pyglet in c:\users\sas\desktop\reinforcement-learning-exercises\rl\lib\site-packages (1.5.27)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\sas\desktop\reinforcement-learning-exercises\rl\lib\site-packages (from gym[box2d]) (1.25.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\sas\desktop\reinforcement-learning-exercises\rl\lib\site-packages (from gym[box2d]) (2.2.1)
# Collecting box2d-py==2.3.5 (from gym[box2d])
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#                                               0.0/374.4 kB ? eta -:--:--
#      ------------------------------------  368.6/374.4 kB 11.6 MB/s eta 0:00:01
#      -------------------------------------- 374.4/374.4 kB 5.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py): started
#   Building wheel for box2d-py (setup.py): finished with status 'error'
#   Running setup.py clean for box2d-py
# Failed to build box2d-py
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [16 lines of output]
#   Using setuptools (version 58.1.0).
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.10
#   creating build\lib.win-amd64-3.10\Box2D
#   copying library\Box2D\Box2D.py -> build\lib.win-amd64-3.10\Box2D
#   copying library\Box2D\__init__.py -> build\lib.win-amd64-3.10\Box2D
#   creating build\lib.win-amd64-3.10\Box2D\b2
#   copying library\Box2D\b2\__init__.py -> build\lib.win-amd64-3.10\Box2D\b2
#   running build_ext
#   building 'Box2D._Box2D' extension
#   swigging Box2D\Box2D.i to Box2D\Box2D_wrap.cpp
#   swig.exe -python -c++ -IBox2D -small -O -includeall -ignoremissing -w201 -globals b2Globals -outdir library\Box2D -keyword -w511 -D_SWIG_KWARGS -o Box2D\Box2D_wrap.cpp Box2D\Box2D.i
#   error: command 'swig.exe' failed: None
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for box2d-py
# ERROR: Could not build wheels for box2d-py, which is required to install pyproject.toml-based projects

# %%
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
import os

# %%
env_name = 'CarRacing-v0'
env = gym.make(env_name)

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    score = 0
    done = False
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score += reward
    print(f"Episode: {episode}   Score: {score}")
env.close()
# Out:
# Track generation: 1033..1301 -> 268-tiles track
# C:\Users\sas\Desktop\Reinforcement-Learning-Exercises\rl\lib\site-packages\pyglet\image\codecs\wic.py:406: UserWarning: [WinError -2147417850] Cannot change thread mode after it is set
#   warnings.warn(str(err))
# Episode: 1   Score: -25.093632958801592
# Track generation: 1160..1454 -> 294-tiles track
# Episode: 2   Score: -35.15358361774793
# Track generation: 989..1248 -> 259-tiles track
# Episode: 3   Score: -22.480620155038974
# Track generation: 1124..1409 -> 285-tiles track
# Episode: 4   Score: -33.098591549296266
# Track generation: 1168..1464 -> 296-tiles track
# Episode: 5   Score: -32.20338983050883

# %%
# Train the model
env = gym.make(env_name)
env = DummyVecEnv([lambda: env])

# %%
log_path = os.path.join("Training", "logs")

# %%
model = PPO('CnnPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps = 250000)
# Out:
# Track generation: 1118..1411 -> 293-tiles track
# Logging to Training\logs\PPO_5
# Track generation: 1004..1259 -> 255-tiles track
# Track generation: 1041..1310 -> 269-tiles track
# -----------------------------
# | time/              |      |
# |    fps             | 33   |
# |    iterations      | 1    |
# |    time_elapsed    | 62   |
# |    total_timesteps | 2048 |
# -----------------------------
# Track generation: 1214..1522 -> 308-tiles track
# Track generation: 1187..1494 -> 307-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 2           |
# |    time_elapsed         | 219         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.004519553 |
# |    clip_fraction        | 0.0799      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.23       |
# |    explained_variance   | -0.00106    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.352       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00803    |
# |    std                  | 0.985       |
# |    value_loss           | 0.75        |
# -----------------------------------------
# Track generation: 1273..1596 -> 323-tiles track
# Track generation: 1144..1434 -> 290-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 3           |
# |    time_elapsed         | 391         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008817015 |
# |    clip_fraction        | 0.087       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.2        |
# |    explained_variance   | 0.103       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.21        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00951    |
# |    std                  | 0.98        |
# |    value_loss           | 0.53        |
# -----------------------------------------
# Track generation: 1176..1474 -> 298-tiles track
# Track generation: 1203..1508 -> 305-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 4           |
# |    time_elapsed         | 556         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009533739 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.2        |
# |    explained_variance   | 0.113       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0989      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.013      |
# |    std                  | 0.983       |
# |    value_loss           | 0.361       |
# -----------------------------------------
# Track generation: 1168..1475 -> 307-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1113..1395 -> 282-tiles track
# Track generation: 1113..1395 -> 282-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 5           |
# |    time_elapsed         | 723         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010919715 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.19       |
# |    explained_variance   | 0.114       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0668      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0115     |
# |    std                  | 0.972       |
# |    value_loss           | 0.339       |
# -----------------------------------------
# Track generation: 1025..1285 -> 260-tiles track
# Track generation: 1086..1361 -> 275-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 6           |
# |    time_elapsed         | 897         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011097159 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.17       |
# |    explained_variance   | 0.566       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.101       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0137     |
# |    std                  | 0.97        |
# |    value_loss           | 0.364       |
# -----------------------------------------
# Track generation: 1059..1328 -> 269-tiles track
# Track generation: 1179..1478 -> 299-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 7           |
# |    time_elapsed         | 1067        |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.016796326 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.15       |
# |    explained_variance   | 0.626       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0336      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0227     |
# |    std                  | 0.957       |
# |    value_loss           | 0.348       |
# -----------------------------------------
# Track generation: 1214..1521 -> 307-tiles track
# Track generation: 1007..1269 -> 262-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 8           |
# |    time_elapsed         | 1242        |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.018771823 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.1        |
# |    explained_variance   | 0.575       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.076       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0214     |
# |    std                  | 0.94        |
# |    value_loss           | 0.257       |
# -----------------------------------------
# Track generation: 1191..1501 -> 310-tiles track
# Track generation: 1131..1425 -> 294-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 9           |
# |    time_elapsed         | 1411        |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.023579925 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.06       |
# |    explained_variance   | 0.677       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0524      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0271     |
# |    std                  | 0.933       |
# |    value_loss           | 0.222       |
# -----------------------------------------
# Track generation: 1112..1395 -> 283-tiles track
# Track generation: 1277..1600 -> 323-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 10          |
# |    time_elapsed         | 1578        |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.018010799 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.05       |
# |    explained_variance   | 0.703       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.023       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.015      |
# |    std                  | 0.932       |
# |    value_loss           | 0.184       |
# -----------------------------------------
# Track generation: 1093..1371 -> 278-tiles track
# Track generation: 1192..1494 -> 302-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 12         |
# |    iterations           | 11         |
# |    time_elapsed         | 1747       |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.01900156 |
# |    clip_fraction        | 0.177      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.04      |
# |    explained_variance   | 0.681      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0103     |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0247    |
# |    std                  | 0.925      |
# |    value_loss           | 0.231      |
# ----------------------------------------
# Track generation: 1042..1306 -> 264-tiles track
# Track generation: 1011..1268 -> 257-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 12          |
# |    time_elapsed         | 1913        |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.022681355 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.01       |
# |    explained_variance   | 0.777       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0105      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0325     |
# |    std                  | 0.918       |
# |    value_loss           | 0.215       |
# -----------------------------------------
# Track generation: 1104..1384 -> 280-tiles track
# Track generation: 1163..1458 -> 295-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 13          |
# |    time_elapsed         | 2083        |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.021596398 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.98       |
# |    explained_variance   | 0.798       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0103     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.031      |
# |    std                  | 0.908       |
# |    value_loss           | 0.256       |
# -----------------------------------------
# Track generation: 1348..1689 -> 341-tiles track
# Track generation: 1263..1583 -> 320-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 14          |
# |    time_elapsed         | 2252        |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.029157816 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.95       |
# |    explained_variance   | 0.486       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0213     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0328     |
# |    std                  | 0.9         |
# |    value_loss           | 0.32        |
# -----------------------------------------
# Track generation: 1090..1366 -> 276-tiles track
# Track generation: 1065..1336 -> 271-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 15          |
# |    time_elapsed         | 2431        |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.029648356 |
# |    clip_fraction        | 0.266       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.91       |
# |    explained_variance   | 0.53        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00592    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0362     |
# |    std                  | 0.885       |
# |    value_loss           | 0.155       |
# -----------------------------------------
# Track generation: 1196..1499 -> 303-tiles track
# Track generation: 1123..1408 -> 285-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 16          |
# |    time_elapsed         | 2597        |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.033492696 |
# |    clip_fraction        | 0.296       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.87       |
# |    explained_variance   | 0.839       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0426     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0438     |
# |    std                  | 0.873       |
# |    value_loss           | 0.189       |
# -----------------------------------------
# Track generation: 955..1205 -> 250-tiles track
# Track generation: 1092..1369 -> 277-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 12         |
# |    iterations           | 17         |
# |    time_elapsed         | 2760       |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.02470311 |
# |    clip_fraction        | 0.237      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.81      |
# |    explained_variance   | 0.823      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0227    |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0262    |
# |    std                  | 0.854      |
# |    value_loss           | 0.151      |
# ----------------------------------------
# Track generation: 1127..1413 -> 286-tiles track
# Track generation: 1100..1379 -> 279-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 12         |
# |    iterations           | 18         |
# |    time_elapsed         | 2934       |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.02556812 |
# |    clip_fraction        | 0.242      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.76      |
# |    explained_variance   | 0.756      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0395    |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0283    |
# |    std                  | 0.842      |
# |    value_loss           | 0.148      |
# ----------------------------------------
# Track generation: 1066..1339 -> 273-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1057..1333 -> 276-tiles track
# Track generation: 1315..1648 -> 333-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 19          |
# |    time_elapsed         | 3109        |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.027227018 |
# |    clip_fraction        | 0.256       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.72       |
# |    explained_variance   | 0.8         |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0517     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0284     |
# |    std                  | 0.83        |
# |    value_loss           | 0.0684      |
# -----------------------------------------
# Track generation: 1380..1729 -> 349-tiles track
# Track generation: 1268..1589 -> 321-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 20          |
# |    time_elapsed         | 3282        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.035619583 |
# |    clip_fraction        | 0.303       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.67       |
# |    explained_variance   | 0.847       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0305     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0302     |
# |    std                  | 0.816       |
# |    value_loss           | 0.107       |
# -----------------------------------------
# Track generation: 1187..1488 -> 301-tiles track
# Track generation: 1195..1498 -> 303-tiles track
# Track generation: 1076..1349 -> 273-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 21          |
# |    time_elapsed         | 3457        |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.033631388 |
# |    clip_fraction        | 0.293       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.64       |
# |    explained_variance   | 0.919       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0492     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0313     |
# |    std                  | 0.81        |
# |    value_loss           | 0.0797      |
# -----------------------------------------
# Track generation: 1080..1354 -> 274-tiles track
# Track generation: 1176..1474 -> 298-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 22          |
# |    time_elapsed         | 3628        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.031235404 |
# |    clip_fraction        | 0.251       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.62       |
# |    explained_variance   | 0.929       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0468     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0246     |
# |    std                  | 0.807       |
# |    value_loss           | 0.0977      |
# -----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 model.learn(total_timesteps = 250000)
#
# File ~\Desktop\Reinforcement-Learning-Exercises\rl\lib\site-packages\stable_baselines3\ppo\ppo.py:308, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     299 def learn(
#     300     self: SelfPPO,
#     301     total_timesteps: int,
#    (...)
#     306     progress_bar: bool = False,
#     307 ) -> SelfPPO:
# --> 308     return super().learn(
#     309         total_timesteps=total_timesteps,
#     310         callback=callback,
#     311         log_interval=log_interval,
#     312         tb_log_name=tb_log_name,
#     313         reset_num_timesteps=reset_num_timesteps,
#     314         progress_bar=progress_bar,
#     315     )
#
# File ~\Desktop\Reinforcement-Learning-Exercises\rl\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:271, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     268         self.logger.record("time/total_timesteps", self.num_timesteps, exclude="tensorboard")
#     269         self.logger.dump(step=self.num_timesteps)
# --> 271     self.train()
#     273 callback.on_training_end()
#     275 return self
#
# File ~\Desktop\Reinforcement-Learning-Exercises\rl\lib\site-packages\stable_baselines3\ppo\ppo.py:272, in PPO.train(self)
#     270 # Optimization step
#     271 self.policy.optimizer.zero_grad()
# --> 272 loss.backward()
#     273 # Clip grad norm
#     274 th.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
#
# File ~\Desktop\Reinforcement-Learning-Exercises\rl\lib\site-packages\torch\_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)
#     485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File ~\Desktop\Reinforcement-Learning-Exercises\rl\lib\site-packages\torch\autograd\__init__.py:200, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     195     retain_graph = create_graph
#     197 # The reason we repeat same the comment below is that
#     198 # some Python versions print out the first line of a multi-line function
#     199 # calls in the traceback and some print out the last line
# --> 200 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     201     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     202     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:
